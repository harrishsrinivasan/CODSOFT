# %% [markdown]
# # IMPORTING LIBRARIES

# %%
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings(action= 'ignore')
plt.style.use(['dark_background'])

# %%
data = pd.read_csv('IRIS.csv')

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
data.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
data.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# species          object
# dtype: object

# %%
data.describe()
# Out:
#        sepal_length  sepal_width  petal_length  petal_width
# count    150.000000   150.000000    150.000000   150.000000
# mean       5.843333     3.054000      3.758667     1.198667
# std        0.828066     0.433594      1.764420     0.763161
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# # GRAPHICAL RELATIONS

# %%
sns.histplot(x = 'sepal_length', data = data, )
plt.xlabel('Sepal Length')
plt.ylabel('frequency')
plt.title('Frequency of Sepal length')
plt.show()

# %%
sns.histplot(x = 'sepal_width', data = data, )
plt.xlabel('Sepal width')
plt.ylabel('frequency')
plt.title('Frequency of Sepal width')
plt.show()

# %%
sns.histplot(x = 'petal_length', data = data, )
plt.xlabel('Petal Length')
plt.ylabel('frequency')
plt.title('Frequency of Petal length')
plt.show()

# %%
sns.histplot(x = 'petal_width', data = data)
plt.xlabel('Petal width')
plt.ylabel('frequency')
plt.title('Frequency of Petal width')
plt.show()

# %%
custom_palatte = ['red','blue','green']
sns.boxplot(x="species", y="petal_length", data=data, palette= custom_palatte)
plt.show()

# %%
custom_palatte = ['red','blue','green']
sns.boxplot(x="species", y="petal_width", data=data, palette= custom_palatte)
plt.show()

# %%
custom_palatte = ['red','blue','green']
sns.boxplot(x="species", y="sepal_length", data=data, palette= custom_palatte)
plt.show()

# %%
custom_palatte = ['red','blue','green']
sns.boxplot(x="species", y="sepal_width", data=data, palette= custom_palatte)
plt.show()

# %%
custom_palatte = ['red','blue','green']
sns.scatterplot(x= 'sepal_length', y = 'sepal_width', hue = 'species', data = data, palette= custom_palatte)
plt.xlabel('Sepal length')
plt.ylabel('Sepal width')
plt.title('Sepal length vs Sepal width across Iris-species')
plt.show()

# %%
custom_palatte = ['red','blue','green']
sns.scatterplot(x= 'petal_length', y = 'petal_width', hue = 'species', data = data, palette= custom_palatte)
plt.xlabel('Petal length')
plt.ylabel('Petal width')
plt.title('Petal length vs Petal width across Iris-Species')
plt.show()

# %%
custom_palatte = ['red','blue','green']
sns.scatterplot(x= 'petal_length', y = 'sepal_length', hue = 'species', data = data, palette= custom_palatte)
plt.xlabel('Petal length')
plt.ylabel('Sepal length')
plt.title('Petal length vs Sepal length across Iris-Species')
plt.show()

# %%
custom_palatte = ['red','blue','green']
sns.scatterplot(x= 'petal_width', y = 'sepal_width', hue = 'species', data = data, palette= custom_palatte)
plt.xlabel('Petal width')
plt.ylabel('Sepal width')
plt.title('Petal width vs Sepal width across Iris-Species')
plt.show()

# %% [markdown]
# # DATA ENCODING

# %%
from sklearn.preprocessing import LabelEncoder
LE = LabelEncoder()

# %%
# Encode the categorial variable species as numeric values
data['species'] = LE.fit_transform(data['species'])
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width  species
# 0           5.1          3.5           1.4          0.2        0
# 1           4.9          3.0           1.4          0.2        0
# 2           4.7          3.2           1.3          0.2        0
# 3           4.6          3.1           1.5          0.2        0
# 4           5.0          3.6           1.4          0.2        0

# %%
#optional
data['species'] = data['species'].astype(float)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    float64
# dtypes: float64(5)
# memory usage: 6.0 KB

# %% [markdown]
# # PREPROCESSING OF DATA

# %%
# defining the target variable 
X = data.drop(columns= ['species'])
Y = data['species']

# %%
# scaling the dataset
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_X = scaler.fit_transform(X)

# %%
#splitting the dataset
from sklearn.model_selection import train_test_split as tts 
x_train, x_test, y_train, y_test = tts(scaled_X, Y, train_size = 0.70, stratify = Y)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((105, 4), (45, 4), (105,), (45,))

# %% [markdown]
# # DECISION TREES MODEL

# %%
from sklearn.tree import DecisionTreeClassifier as DTC 
classifier = DTC(class_weight= 'balanced')
classifier = DTC()

# %%
classifier.fit(x_train, y_train)
predicted_values = classifier.predict(x_train)

# %%
#training set evaluation
from sklearn.metrics import classification_report
print(classification_report(y_train, predicted_values))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        35
#          1.0       1.00      1.00      1.00        35
#          2.0       1.00      1.00      1.00        35
#
#     accuracy                           1.00       105
#    macro avg       1.00      1.00      1.00       105
# weighted avg       1.00      1.00      1.00       105

# %%
#test set evaluation
predicted_values = classifier.predict(x_test)
print(classification_report(y_test, predicted_values))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        15
#          1.0       0.83      1.00      0.91        15
#          2.0       1.00      0.80      0.89        15
#
#     accuracy                           0.93        45
#    macro avg       0.94      0.93      0.93        45
# weighted avg       0.94      0.93      0.93        45

# %%
print("Accuracy: ", classifier.score(x_test, y_test) * 100)
# Out:
# Accuracy:  93.33333333333333

# %% [markdown]
# the accuracy of the model using decision trees is 95.5555 percent

# %% [markdown]
# # LOGISTIC REGRESSION MODEL

# %%
# logistic regression
from sklearn.linear_model import LogisticRegression as LR
classifier = LR(class_weight = 'balanced')

# %%
classifier.fit(x_train, y_train)
predicted_values = classifier.predict(x_train)
predicted_probabilities = classifier.predict_proba(x_test)

# %%
#training set evaluation
from sklearn.metrics import classification_report
k = classification_report(y_train, predicted_values)
print(k)
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        35
#          1.0       1.00      0.94      0.97        35
#          2.0       0.95      1.00      0.97        35
#
#     accuracy                           0.98       105
#    macro avg       0.98      0.98      0.98       105
# weighted avg       0.98      0.98      0.98       105

# %%
#test set evaluation
predicted_values = classifier.predict(x_test)
print(classification_report(y_test, predicted_values))
# Out:
#               precision    recall  f1-score   support
#
#          0.0       1.00      1.00      1.00        15
#          1.0       0.79      1.00      0.88        15
#          2.0       1.00      0.73      0.85        15
#
#     accuracy                           0.91        45
#    macro avg       0.93      0.91      0.91        45
# weighted avg       0.93      0.91      0.91        45

# %%
print("Accuracy: ", classifier.score(x_test, y_test) * 100)
# Out:
# Accuracy:  91.11111111111111

# %% [markdown]
# the accuracy of the model using logistic regression is 93.3333 percent
